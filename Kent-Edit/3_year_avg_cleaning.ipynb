# %%
import pandas as pd
import csv
import os
import numpy
from pprint import pprint

# %%
median_csv = pd.read_csv("City_MedianListingPrice_AllHomes.csv", index_col=None, encoding = "ISO-8859-1")

geo_coords_csv = pd.read_csv("1k_largest_cities_geo_coords.csv", index_col=None)

del geo_coords_csv['State']
del geo_coords_csv['Rank']
del geo_coords_csv['Growth From 2000 to 2013']
del geo_coords_csv['Population']

# %%
largest_100_df = median_csv.sort_values('SizeRank')[0:100]
largest_100_df_renamed = largest_100_df.rename(columns={"RegionName": "City"})

merge_table = pd.merge(largest_100_df_renamed, geo_coords_csv, on="City", how="left")
merge_table_drop = merge_table.drop_duplicates('City')

# %%
merge_table_drop['Moving_Growth_2010_12'] = (((((median_csv['2010-02']/median_csv['2010-01']-1)+(median_csv['2010-03']/median_csv['2010-02']-1)+ \
(median_csv['2010-04']/median_csv['2010-03']-1)+(median_csv['2010-05']/median_csv['2010-04']-1)+(median_csv['2010-06']/median_csv['2010-05']-1)+\
(median_csv['2010-07']/median_csv['2010-06']-1)+(median_csv['2010-08']/median_csv['2010-07']-1)+(median_csv['2010-09']/median_csv['2010-08']-1)+\
(median_csv['2010-10']/median_csv['2010-09']-1)+(median_csv['2010-11']/median_csv['2010-10']-1)+(median_csv['2010-12']/median_csv['2010-11']-1))/12))+\

((((median_csv['2011-02']/median_csv['2011-01']-1)+(median_csv['2011-03']/median_csv['2011-02']-1)+ \
(median_csv['2011-04']/median_csv['2011-03']-1)+(median_csv['2011-05']/median_csv['2011-04']-1)+(median_csv['2011-06']/median_csv['2011-05']-1)+\
(median_csv['2011-07']/median_csv['2011-06']-1)+(median_csv['2011-08']/median_csv['2011-07']-1)+(median_csv['2011-09']/median_csv['2011-08']-1)+\
(median_csv['2011-10']/median_csv['2011-09']-1)+(median_csv['2011-11']/median_csv['2011-10']-1)+(median_csv['2011-12']/median_csv['2011-11']-1))/12))+\

((((median_csv['2012-02']/median_csv['2012-01']-1)+(median_csv['2012-03']/median_csv['2012-02']-1)+ \
(median_csv['2012-04']/median_csv['2012-03']-1)+(median_csv['2012-05']/median_csv['2012-04']-1)+(median_csv['2012-06']/median_csv['2012-05']-1)+\
(median_csv['2012-07']/median_csv['2012-06']-1)+(median_csv['2012-08']/median_csv['2012-07']-1)+(median_csv['2012-09']/median_csv['2012-08']-1)+\
(median_csv['2012-10']/median_csv['2012-09']-1)+(median_csv['2011-11']/median_csv['2012-10']-1)+(median_csv['2012-12']/median_csv['2012-11']-1))/12))/3)
# Out:
# C:\Users\khuynh\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
merge_table_drop['Moving_Growth_2013_15'] = (((((median_csv['2013-02']/median_csv['2013-01']-1)+(median_csv['2013-03']/median_csv['2013-02']-1)+ \
(median_csv['2013-04']/median_csv['2013-03']-1)+(median_csv['2013-05']/median_csv['2013-04']-1)+(median_csv['2013-06']/median_csv['2013-05']-1)+\
(median_csv['2013-07']/median_csv['2013-06']-1)+(median_csv['2013-08']/median_csv['2013-07']-1)+(median_csv['2013-09']/median_csv['2013-08']-1)+\
(median_csv['2013-10']/median_csv['2013-09']-1)+(median_csv['2013-11']/median_csv['2013-10']-1)+(median_csv['2013-12']/median_csv['2013-11']-1))/12))+\

((((median_csv['2014-02']/median_csv['2014-01']-1)+(median_csv['2014-03']/median_csv['2014-02']-1)+ \
(median_csv['2014-04']/median_csv['2014-03']-1)+(median_csv['2014-05']/median_csv['2014-04']-1)+(median_csv['2014-06']/median_csv['2014-05']-1)+\
(median_csv['2014-07']/median_csv['2014-06']-1)+(median_csv['2014-08']/median_csv['2014-07']-1)+(median_csv['2014-09']/median_csv['2014-08']-1)+\
(median_csv['2014-10']/median_csv['2014-09']-1)+(median_csv['2014-11']/median_csv['2014-10']-1)+(median_csv['2014-12']/median_csv['2014-11']-1))/12))+\

((((median_csv['2015-02']/median_csv['2015-01']-1)+(median_csv['2015-03']/median_csv['2015-02']-1)+ \
(median_csv['2015-04']/median_csv['2015-03']-1)+(median_csv['2015-05']/median_csv['2015-04']-1)+(median_csv['2015-06']/median_csv['2015-05']-1)+\
(median_csv['2015-07']/median_csv['2015-06']-1)+(median_csv['2015-08']/median_csv['2015-07']-1)+(median_csv['2015-09']/median_csv['2015-08']-1)+\
(median_csv['2015-10']/median_csv['2015-09']-1)+(median_csv['2015-11']/median_csv['2015-10']-1)+(median_csv['2015-12']/median_csv['2015-11']-1))/12))/3)
# Out:
# C:\Users\khuynh\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
merge_table_drop['Moving_Growth_2016_18'] = (((((median_csv['2016-02']/median_csv['2016-01']-1)+(median_csv['2016-03']/median_csv['2016-02']-1)+ \
(median_csv['2016-04']/median_csv['2016-03']-1)+(median_csv['2016-05']/median_csv['2016-04']-1)+(median_csv['2016-06']/median_csv['2016-05']-1)+\
(median_csv['2016-07']/median_csv['2016-06']-1)+(median_csv['2016-08']/median_csv['2016-07']-1)+(median_csv['2016-09']/median_csv['2016-08']-1)+\
(median_csv['2016-10']/median_csv['2016-09']-1)+(median_csv['2016-11']/median_csv['2016-10']-1)+(median_csv['2016-12']/median_csv['2016-11']-1))/12))+\

((((median_csv['2017-02']/median_csv['2017-01']-1)+(median_csv['2017-03']/median_csv['2017-02']-1)+ \
(median_csv['2017-04']/median_csv['2017-03']-1)+(median_csv['2017-05']/median_csv['2017-04']-1)+(median_csv['2017-06']/median_csv['2017-05']-1)+\
(median_csv['2017-07']/median_csv['2017-06']-1)+(median_csv['2017-08']/median_csv['2017-07']-1)+(median_csv['2017-09']/median_csv['2017-08']-1)+\
(median_csv['2017-10']/median_csv['2017-09']-1)+(median_csv['2017-11']/median_csv['2017-10']-1)+(median_csv['2017-12']/median_csv['2017-11']-1))/12))+\

((((median_csv['2018-02']/median_csv['2018-01']-1)+(median_csv['2018-03']/median_csv['2018-02']-1)+ \
(median_csv['2018-04']/median_csv['2018-03']-1)+(median_csv['2018-05']/median_csv['2018-04']-1)+(median_csv['2018-06']/median_csv['2018-05']-1)+\
(median_csv['2018-07']/median_csv['2018-06']-1)+(median_csv['2018-08']/median_csv['2018-07']-1)+(median_csv['2018-09']/median_csv['2018-08']-1)+\
(median_csv['2018-10']/median_csv['2018-09']-1))/10))/3)
# Out:
# C:\Users\khuynh\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
## calculate average median price for 2010 - 2012
merge_table_drop['Avg_Median_2010_12'] = ((median_csv['2010-01'] + median_csv['2010-02'] + median_csv['2010-03'] + median_csv['2010-04'] \
+ median_csv['2010-05'] + median_csv['2010-06'] + median_csv['2010-07'] + median_csv['2010-08'] + median_csv['2010-09'] +\
median_csv['2010-10'] + median_csv['2010-11'] + median_csv['2010-12'] +\
median_csv['2011-01'] + median_csv['2011-02'] + median_csv['2011-03'] + median_csv['2011-04'] + median_csv['2011-05'] + \
median_csv['2011-06'] + median_csv['2011-07'] + median_csv['2011-08'] + median_csv['2011-09'] + median_csv['2011-10'] + median_csv['2011-11'] + \
median_csv['2011-12'] + \
median_csv['2012-01'] + median_csv['2012-02'] + median_csv['2012-03'] + median_csv['2012-04'] + median_csv['2012-05'] +\
median_csv['2012-06'] + median_csv['2012-07'] + median_csv['2012-08'] + median_csv['2012-09'] + median_csv['2012-10'] +\
median_csv['2012-11'] + median_csv['2012-12'])/36)
# Out:
# C:\Users\khuynh\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
## calculate average median price for 2010 - 2012
merge_table_drop['Avg_Median_2013_15'] = ((median_csv['2013-01'] + median_csv['2013-02'] + median_csv['2013-03'] + median_csv['2013-04'] \
+ median_csv['2013-05'] + median_csv['2013-06'] + median_csv['2013-07'] + median_csv['2013-08'] + median_csv['2013-09'] +\
median_csv['2013-10'] + median_csv['2013-11'] + median_csv['2013-12'] +\
median_csv['2014-01'] + median_csv['2014-02'] + median_csv['2014-03'] + median_csv['2014-04'] + median_csv['2014-05'] + \
median_csv['2014-06'] + median_csv['2014-07'] + median_csv['2014-08'] + median_csv['2014-09'] + median_csv['2014-10'] + median_csv['2014-11'] + \
median_csv['2014-12'] + \
median_csv['2015-01'] + median_csv['2015-02'] + median_csv['2015-03'] + median_csv['2015-04'] + median_csv['2015-05'] +\
median_csv['2015-06'] + median_csv['2015-07'] + median_csv['2015-08'] + median_csv['2015-09'] + median_csv['2015-10'] +\
median_csv['2015-11'] + median_csv['2015-12'])/36)
# Out:
# C:\Users\khuynh\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
## calculate average median price for 2016 - 2018
merge_table_drop['Avg_Median_2016_18'] = ((median_csv['2016-01'] + median_csv['2016-02'] + median_csv['2016-03'] + median_csv['2016-04'] \
+ median_csv['2016-05'] + median_csv['2016-06'] + median_csv['2016-07'] + median_csv['2016-08'] + median_csv['2016-09'] +\
median_csv['2016-10'] + median_csv['2016-11'] + median_csv['2016-12'] +\
median_csv['2017-01'] + median_csv['2017-02'] + median_csv['2017-03'] + median_csv['2017-04'] + median_csv['2017-05'] + \
median_csv['2017-06'] + median_csv['2017-07'] + median_csv['2017-08'] + median_csv['2017-09'] + median_csv['2017-10'] + median_csv['2017-11'] + \
median_csv['2017-12'] + \
median_csv['2018-01'] + median_csv['2018-02'] + median_csv['2018-03'] + median_csv['2018-04'] + median_csv['2018-05'] +\
median_csv['2018-06'] + median_csv['2018-07'] + median_csv['2018-08'] + median_csv['2018-09'] + median_csv['2018-10'])/34)
# Out:
# C:\Users\khuynh\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
for x in range(10,19):
    if x != 18:
        del merge_table_drop[f'20{x}-01']
        del merge_table_drop[f'20{x}-02']
        del merge_table_drop[f'20{x}-03']
        del merge_table_drop[f'20{x}-04']
        del merge_table_drop[f'20{x}-05']
        del merge_table_drop[f'20{x}-06']
        del merge_table_drop[f'20{x}-07']
        del merge_table_drop[f'20{x}-08']
        del merge_table_drop[f'20{x}-09']
        del merge_table_drop[f'20{x}-10']
        del merge_table_drop[f'20{x}-11']
        del merge_table_drop[f'20{x}-12']
    else:
        del merge_table_drop[f'20{x}-01']
        del merge_table_drop[f'20{x}-02']
        del merge_table_drop[f'20{x}-03']
        del merge_table_drop[f'20{x}-04']
        del merge_table_drop[f'20{x}-05']
        del merge_table_drop[f'20{x}-06']
        del merge_table_drop[f'20{x}-07']
        del merge_table_drop[f'20{x}-08']
        del merge_table_drop[f'20{x}-09']
        del merge_table_drop[f'20{x}-10']

# %%
merge_table_drop
# Out:
#                  City State                                       Metro  \
# 0            New York    NY                 New York-Newark-Jersey City
# 1         Los Angeles    CA              Los Angeles-Long Beach-Anaheim
# 2             Chicago    IL                    Chicago-Naperville-Elgin
# 3             Houston    TX            Houston-The Woodlands-Sugar Land
# 4         San Antonio    TX                   San Antonio-New Braunfels
# 5        Philadelphia    PA              Philadelphia-Camden-Wilmington
# 6             Phoenix    AZ                     Phoenix-Mesa-Scottsdale
# 7           Las Vegas    NV                Las Vegas-Henderson-Paradise
# 8           San Diego    CA                          San Diego-Carlsbad
# 9              Dallas    TX                 Dallas-Fort Worth-Arlington
# 10           San Jose    CA              San Jose-Sunnyvale-Santa Clara
# 11             Austin    TX                           Austin-Round Rock
# ...

# %%
merge_table_drop.round({"Moving_Growth_2010_12":4, "Moving_Growth_2013_15":4, "Moving_Growth_2016_18":4, "Avg_Median_2010_12":2,\
"Avg_Median_2013_15":2,"Avg_Median_2016_18":2})
# Out:
#                  City State                                       Metro  \
# 0            New York    NY                 New York-Newark-Jersey City
# 1         Los Angeles    CA              Los Angeles-Long Beach-Anaheim
# 2             Chicago    IL                    Chicago-Naperville-Elgin
# 3             Houston    TX            Houston-The Woodlands-Sugar Land
# 4         San Antonio    TX                   San Antonio-New Braunfels
# 5        Philadelphia    PA              Philadelphia-Camden-Wilmington
# 6             Phoenix    AZ                     Phoenix-Mesa-Scottsdale
# 7           Las Vegas    NV                Las Vegas-Henderson-Paradise
# 8           San Diego    CA                          San Diego-Carlsbad
# 9              Dallas    TX                 Dallas-Fort Worth-Arlington
# 10           San Jose    CA              San Jose-Sunnyvale-Santa Clara
# 11             Austin    TX                           Austin-Round Rock
# ...

# %%
merge_table_drop.to_csv("Clean_Growth_Coords.csv", index=False, header=True)
